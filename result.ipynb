# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

pathCWD = os.getcwd() + "/data/"
pathGWPlacement = pathCWD + "model/output/biobj_Placement_1s_36x1Gv_50D.dat"
dataGWPlacement = pd.read_csv(pathGWPlacement, sep=",")
dfGWPlacement = pd.DataFrame(dataGWPlacement)

pathEDPlacement = pathCWD + "model/output/biobj_DevicePlacement_1s_36x1Gv_50D.dat"
dataEDPlacement = pd.read_csv(pathEDPlacement, sep=",")
dfEDPlacement = pd.DataFrame(dataEDPlacement)

pathAssociationPlacement = pathCWD + "model/output/biobj_QoSResults_1s_36x1Gv_50D.dat"
dataAssociationPlacement = pd.read_csv(pathAssociationPlacement, sep=",")
dfAssociationPlacement = pd.DataFrame(dataAssociationPlacement)

x = []
y = []
for i in range(len(dfAssociationPlacement["device"].array)):
    device = dfAssociationPlacement["device"].array[i]
    gateway = dfAssociationPlacement["gateway"].array[i]
    x.append([dfGWPlacement.loc[dfGWPlacement['id'] == gateway]['x'].item(), dfEDPlacement.loc[dfEDPlacement['device'] == device]['x'].item()])
    y.append([dfGWPlacement.loc[dfGWPlacement['id'] == gateway]['y'].item(), dfEDPlacement.loc[dfEDPlacement['device'] == device]['y'].item()])

fig = plt.plot(figsize=(9, 9))

color1 = '#6B2D97'
color2 = '#96753C'
alpha = 0.9

for i in range(len(dfAssociationPlacement["device"].array)):
    plt.annotate(dfEDPlacement['device'][i], (dfEDPlacement['x'][i]-150, dfEDPlacement['y'][i] + 100), zorder=15)
    plt.plot(x[i], y[i], '-', c='grey', zorder=0)

plt.scatter(dfGWPlacement['x'], dfGWPlacement['y'], c=color1, s=160, marker=(5, 1), zorder=10)
plt.scatter(dfEDPlacement['x'], dfEDPlacement['y'], c=color2, s=40, zorder=10)

plt.yticks([0, 1000, 2000, 3000, 2000, 5000, 6000, 7000, 8000, 9000, 10000])
plt.xticks([0, 1000, 2000, 3000, 2000, 5000, 6000, 7000, 8000, 9000, 10000])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

pathCWD = os.getcwd() + "/data/"
pathGWPlacement = pathCWD + "results/biobj_PacketPerGateway_7_25x80.dat"
dataGWPlacement = pd.read_csv(pathGWPlacement, sep=",")
dfGWPlacement = pd.DataFrame(dataGWPlacement)

pathEDPlacement = pathCWD + "results/biobj_EDParameters_7_25x80.dat"
dataEDPlacement = pd.read_csv(pathEDPlacement, sep=",")
dfEDPlacement = pd.DataFrame(dataEDPlacement)

pathAssociationPlacement = pathCWD + "results/biobj_transmissionPackets_7_25x80.dat"
dataAssociationPlacement = pd.read_csv(pathAssociationPlacement, sep=",")
dfAssociationPlacement = pd.DataFrame(dataAssociationPlacement)

associations = []
for row in dfAssociationPlacement.iterrows():
    if [row[1][0], row[1][1]] not in associations:
        associations.append([row[1][0], row[1][1]])

dotsize = 25
x = []
y = []
for i in range(len(associations)):
    device = associations[i][0]
    gateway = associations[i][1]
    if gateway == 0:
        continue
    x.append([dfGWPlacement.loc[dfGWPlacement['gwID'] == gateway]['x'].item(), dfEDPlacement.loc[dfEDPlacement['device'] == device]['x'].item()])
    y.append([dfGWPlacement.loc[dfGWPlacement['gwID'] == gateway]['y'].item(), dfEDPlacement.loc[dfEDPlacement['device'] == device]['y'].item()])

fig, ax = plt.subplots(1, 2, figsize=(18, 9))

color1 = '#6B2D97'
color2 = '#96753C'
alpha = 0.9

for i in range(len(x)-1):
    ax[0].annotate(dfEDPlacement['device'][i], (dfEDPlacement['x'][i]-150, dfEDPlacement['y'][i] + 100), zorder=15)
    ax[0].plot(x[i], y[i], '-', c='grey', zorder=0)

ax[0].scatter(dfGWPlacement['x'], dfGWPlacement['y'], c=color1, s=160, marker=(5, 1), zorder=10)
ax[0].scatter(dfEDPlacement['x'], dfEDPlacement['y'], c=color2, s=dotSize, zorder=10)

ax[0].set_yticks([0, 1000, 2000, 3000, 2000, 5000, 6000, 7000, 8000, 9000, 10000])
ax[0].set_xticks([0, 1000, 2000, 3000, 2000, 5000, 6000, 7000, 8000, 9000, 10000])

# -----------------------------------------------------------------------------------

pathGWPlacement = pathCWD + "results/biobj_PacketPerGateway_7_25x70.dat"
dataGWPlacement = pd.read_csv(pathGWPlacement, sep=",")
dfGWPlacement = pd.DataFrame(dataGWPlacement)

pathEDPlacement = pathCWD + "results/biobj_EDParameters_7_25x70.dat"
dataEDPlacement = pd.read_csv(pathEDPlacement, sep=",")
dfEDPlacement = pd.DataFrame(dataEDPlacement)

pathAssociationPlacement = pathCWD + "results/biobj_transmissionPackets_7_25x70.dat"
dataAssociationPlacement = pd.read_csv(pathAssociationPlacement, sep=",")
dfAssociationPlacement = pd.DataFrame(dataAssociationPlacement)

associations = []
for row in dfAssociationPlacement.iterrows():
    if [row[1][0], row[1][1]] not in associations:
        associations.append([row[1][0], row[1][1]])

x = []
y = []
for i in range(len(associations)):
    device = associations[i][0]
    gateway = associations[i][1]
    if gateway == 0:
        continue
    x.append([dfGWPlacement.loc[dfGWPlacement['gwID'] == gateway]['x'].item(), dfEDPlacement.loc[dfEDPlacement['device'] == device]['x'].item()])
    y.append([dfGWPlacement.loc[dfGWPlacement['gwID'] == gateway]['y'].item(), dfEDPlacement.loc[dfEDPlacement['device'] == device]['y'].item()])

color1 = '#6B2D97'
color2 = '#96753C'
alpha = 0.9

for i in range(len(x)-1):
    ax[1].annotate(dfEDPlacement['device'][i], (dfEDPlacement['x'][i]-150, dfEDPlacement['y'][i] + 100), zorder=15)
    ax[1].plot(x[i], y[i], '-', c='grey', zorder=0)

ax[1].scatter(dfGWPlacement['x'], dfGWPlacement['y'], c=color1, s=160, marker=(5, 1), zorder=10)
ax[1].scatter(dfEDPlacement['x'], dfEDPlacement['y'], c=color2, s=40, zorder=10)

ax[1].set_yticks([0, 1000, 2000, 3000, 2000, 5000, 6000, 7000, 8000, 9000, 10000])
ax[1].set_xticks([0, 1000, 2000, 3000, 2000, 5000, 6000, 7000, 8000, 9000, 10000])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 32
#      30     if gateway == 0:
#      31         continue
# ---> 32     x.append([dfGWPlacement.loc[dfGWPlacement['gwID'] == gateway]['x'].item(), dfEDPlacement.loc[dfEDPlacement['device'] == device]['x'].item()])
#      33     y.append([dfGWPlacement.loc[dfGWPlacement['gwID'] == gateway]['y'].item(), dfEDPlacement.loc[dfEDPlacement['device'] == device]['y'].item()])
#      35 fig, ax = plt.subplots(1, 2, figsize=(18, 9))
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/base.py:350, in IndexOpsMixin.item(self)
#     348 if len(self) == 1:
#     349     return next(iter(self))
# --> 350 raise ValueError("can only convert an array of size 1 to a Python scalar")
#
# ValueError: can only convert an array of size 1 to a Python scalar

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

means_alt = []
error_alt = []
means_biobj = []
error_biobj = []
means_opt = []
error_opt = []
indexes = []

pathCWD = os.getcwd() + "/data/"
for i in range(2,9):
    indexes.append(i**2)

    # ---- Alternative Biobjective ----
    pathFile = pathCWD + "results/alt_biobj_PacketDelivery_"+ str(i**2) +"x50.dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_alt.append(np.mean(delivery) * 100)
    error_alt.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

    # ---- Biobjective ----
    pathFile = pathCWD + "results/biobj_PacketDelivery_"+ str(i**2) +"x50.dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_biobj.append(np.mean(delivery) * 100)
    error_biobj.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

    # ---- Optimal ----
    pathFile = pathCWD + "results/opt_PacketDelivery_"+ str(i**2) +"x50.dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_opt.append(np.mean(delivery) * 100)
    error_opt.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

fig = plt.figure(figsize=(7, 3))

color1 = '#6B2D97'
color2 = '#96753C'
color3 = '#1E9650'
alpha = 0.9


plt.errorbar(range(len(means_alt)), means_alt, error_alt, color=color1, marker='o', 
             label='Alternative Biobjective', capsize=6, lw=2, capthick=2)

plt.errorbar(range(len(means_alt)), means_biobj, error_biobj, color=color2, marker='o', 
             label='Biobjective', capsize=6, lw=2, capthick=2)

plt.errorbar(range(len(means_alt)), means_opt, error_opt, color=color3, marker='o', 
             label='Minimize UAVs', capsize=6, lw=2, capthick=2)


plt.xticks(range(len(means_alt)), indexes)
plt.xlabel("Virtual Positions")
plt.ticklabel_format()
plt.ylabel("Packet Delivery (%)")
plt.grid(True, 'major', 'y', linestyle='--')
plt.legend(loc='best')

# fig.suptitle('Solving Time by Number of Virtual Positions')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

means_alt = []
error_alt = []
means_biobj = []
error_biobj = []
indexes = []
solve_rate = {4: 0.0, 9: 0.0, 16: 0.0, 25: 0.0, 36: 0.0, 49: 0.0, 64: 0.0}
solved_seeds = {4: [], 9: [], 16: [], 25: [], 36: [], 49: [], 64: []}

pathCWD = os.getcwd() + "/data/"
pathFile = pathCWD + "model/output/beta_biobj_solutions.dat"
dataSolAlt = pd.read_csv(pathFile, sep=",")
dfSolAlt = pd.DataFrame(dataSolAlt)

for row in dfSolAlt.iterrows():
    pos = row[1]['numVirtualPositions']
    if row[1]['solveTime'] < 1800.0:
        solve_rate[pos] += 10
        solved_seeds[pos].append(row[1]['seed'])

for i in range(2,9):
    indexes.append(i**2)

    # ---- Biobjective Beta ----
    pathFile = pathCWD + "results/beta_biobj_PacketDelivery_"+ str(i**2) +"x50.dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        if row[1]['seed'] not in solved_seeds[i**2]:
            continue
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_alt.append(np.mean(delivery) * 100)
    error_alt.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

    # ---- Biobjective Alpha ----
    pathFile = pathCWD + "results/biobj_PacketDelivery_"+ str(i**2) +"x50.dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_biobj.append(np.mean(delivery) * 100)
    error_biobj.append(np.std(delivery) * 100/np.sqrt(len(delivery)))


fig, ax1 = plt.subplots(figsize=(7, 3))

color1 = '#6B2D97'
color2 = '#96753C'
color3 = '#1E9650'
alpha = 0.4

ax1.errorbar(range(len(means_alt)), means_biobj, error_biobj, color=color2, marker='o', 
             label='Biobjective Alpha', capsize=6, lw=2, capthick=2, zorder=5)
ax1.errorbar(range(len(means_alt)), means_alt, error_alt, color=color1, marker='o', 
             label='Biobjective Beta', capsize=6, lw=2, capthick=2, zorder=5)

ax1.set_xticks(range(len(means_alt)), indexes)
ax1.set_xlabel("Virtual Positions")
ax1.set_ylabel("Packet Delivery (%)")
ax1.grid(True, 'major', 'y', linestyle='--', color='darkgrey')
ax1.legend(loc='best')

ax2 = ax1.twinx()

ax2.bar(range(len(means_alt)), solve_rate.values(), width=0.6, color=color1, alpha=alpha, zorder=0)

ax2.set_ylabel('Instance Solve Rate (%)', color=color1)
ax2.tick_params(axis='y', which='major', colors=color1)

ax1.set_zorder(ax2.get_zorder()+1)
ax1.set_frame_on(False)
# fig.suptitle('Solving Time by Number of Virtual Positions')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

means_alt = []
error_alt = []
means_biobj = []
error_biobj = []
means_opt = []
error_opt = []
indexes = []

pathCWD = os.getcwd() + "/data/"
pathFile = pathCWD + "model/output/beta_biobj_solutions.dat"
dataSolAlt = pd.read_csv(pathFile, sep=",")
dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_solutions.dat"
dataSolBiobj = pd.read_csv(pathFile, sep=",")
dfSolBiobj = pd.DataFrame(dataSolBiobj)

pathFile = pathCWD + "model/output/opt_solutions.dat"
dataSolOpt = pd.read_csv(pathFile, sep=",")
dfSolOpt = pd.DataFrame(dataSolOpt)

for i in range(2,9):
    indexes.append(i**2)

    aux = dfSolAlt[dfSolAlt['solveTime'] < 1800.0]
    times = aux.loc[aux['numVirtualPositions'] == i**2]['solveTime'].array
    means_alt.append(np.mean(times))
    error_alt.append(np.std(times)/np.sqrt(len(times)))

    times = dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == i**2]['solveTime'].array
    means_biobj.append(np.mean(times))
    error_biobj.append(np.std(times)/np.sqrt(len(times)))

    times = dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == i**2]['solveTime'].array
    means_opt.append(np.mean(times))
    error_opt.append(np.std(times)/np.sqrt(len(times)))

fig = plt.figure(figsize=(7, 3))

color1 = '#6B2D97'
color2 = '#96753C'
color3 = '#1E9650'
alpha = 0.9

plt.errorbar(range(len(means_alt)), means_biobj, error_biobj, color=color2, marker='o', 
             label='Biobjective Alpha', capsize=6, lw=2, capthick=2)

plt.errorbar(range(len(means_alt)), means_alt, error_alt, color=color1, marker='o', 
             label='Biobjective Beta', capsize=6, lw=2, capthick=2)

plt.errorbar(range(len(means_alt)), means_opt, error_opt, color=color3, marker='o', 
             label='Minimize UAVs', capsize=6, lw=2, capthick=2)


plt.xticks(range(len(means_alt)), indexes)
plt.xlabel("Virtual Positions")
plt.ticklabel_format()
plt.ylabel("Solve Time (s)")
plt.grid(True, 'major', 'y', linestyle='--')
plt.legend(loc='best')

# fig.suptitle('Solving Time by Number of Virtual Positions')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

sfDist_alt = []
sfDist_biobj = []
sfDist_opt = []
indexes = []

pathCWD = os.getcwd() + "/data/"
pathFile = pathCWD + "model/output/beta_biobj_solutions.dat"
dataSolAlt = pd.read_csv(pathFile, sep=",")
dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_solutions.dat"
dataSolBiobj = pd.read_csv(pathFile, sep=",")
dfSolBiobj = pd.DataFrame(dataSolBiobj)

pathFile = pathCWD + "model/output/opt_solutions.dat"
dataSolOpt = pd.read_csv(pathFile, sep=",")
dfSolOpt = pd.DataFrame(dataSolOpt)

size = 3

fig, ax1 = plt.subplots(figsize=(10, 5))

color1 = '#6B2D97'
color2 = '#96753C'
color3 = '#1E9650'
alpha = 0.9
dotSize = 30

dfSolAlt = dfSolAlt[dfSolAlt['solveTime'] < 1800.0]
numRows = len(dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == size**2]['sf7'].array)
plt.scatter([0 + 0.02*i -0.4 for i in range(numRows)], dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == size**2]['sf7'].array, c=color1, s=dotSize, zorder=10, label='Biobjective Beta')
plt.scatter([1 + 0.02*i -0.4 for i in range(numRows)], dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == size**2]['sf8'].array, c=color1, s=dotSize, zorder=10)
plt.scatter([2 + 0.02*i -0.4 for i in range(numRows)], dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == size**2]['sf9'].array, c=color1, s=dotSize, zorder=10)
plt.scatter([3 + 0.02*i -0.4 for i in range(numRows)], dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == size**2]['sf10'].array, c=color1, s=dotSize, zorder=10)
plt.scatter([4 + 0.02*i -0.4 for i in range(numRows)], dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == size**2]['sf11'].array, c=color1, s=dotSize, zorder=10)
plt.scatter([5 + 0.02*i -0.4 for i in range(numRows)], dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == size**2]['sf12'].array, c=color1, s=dotSize, zorder=10)

plt.scatter([0 + 0.02*i -0.1 for i in range(10)], dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == size**2]['sf7'].array, c=color2, s=dotSize, zorder=10, label='Biobjective Alpha')
plt.scatter([1 + 0.02*i -0.1 for i in range(10)], dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == size**2]['sf8'].array, c=color2, s=dotSize, zorder=10)
plt.scatter([2 + 0.02*i -0.1 for i in range(10)], dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == size**2]['sf9'].array, c=color2, s=dotSize, zorder=10)
plt.scatter([3 + 0.02*i -0.1 for i in range(10)], dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == size**2]['sf10'].array, c=color2, s=dotSize, zorder=10)
plt.scatter([4 + 0.02*i -0.1 for i in range(10)], dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == size**2]['sf11'].array, c=color2, s=dotSize, zorder=10)
plt.scatter([5 + 0.02*i -0.1 for i in range(10)], dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == size**2]['sf12'].array, c=color2, s=dotSize, zorder=10)

plt.scatter([0 + 0.2 + 0.02*i for i in range(10)], dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == size**2]['sf7'].array, c=color3, s=dotSize, zorder=10, label='Minimize UAVs')
plt.scatter([1 + 0.2 + 0.02*i for i in range(10)], dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == size**2]['sf8'].array, c=color3, s=dotSize, zorder=10)
plt.scatter([2 + 0.2 + 0.02*i for i in range(10)], dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == size**2]['sf9'].array, c=color3, s=dotSize, zorder=10)
plt.scatter([3 + 0.2 + 0.02*i for i in range(10)], dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == size**2]['sf10'].array, c=color3, s=dotSize, zorder=10)
plt.scatter([4 + 0.2 + 0.02*i for i in range(10)], dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == size**2]['sf11'].array, c=color3, s=dotSize, zorder=10)
plt.scatter([5 + 0.2 + 0.02*i for i in range(10)], dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == size**2]['sf12'].array, c=color3, s=dotSize, zorder=10)

plt.xticks(range(6), ['SF7', 'SF8', 'SF9', 'SF10', 'SF11', 'SF12'])
plt.xlabel("Spreading Factor")
plt.ticklabel_format()
plt.ylabel("Number of Devices")
plt.grid(True, 'major', 'y', linestyle='--')
plt.legend(loc='best')

# fig.suptitle('Solving Time by Number of Virtual Positions')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

means_alt = []
error_alt = []
means_biobj = []
error_biobj = []
means_opt = []
error_opt = []
indexes = []

pathCWD = os.getcwd() + "/data/"
pathFile = pathCWD + "model/output/beta_biobj_solutions.dat"
dataSolAlt = pd.read_csv(pathFile, sep=",")
dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_solutions.dat"
dataSolBiobj = pd.read_csv(pathFile, sep=",")
dfSolBiobj = pd.DataFrame(dataSolBiobj)

pathFile = pathCWD + "model/output/opt_solutions.dat"
dataSolOpt = pd.read_csv(pathFile, sep=",")
dfSolOpt = pd.DataFrame(dataSolOpt)

for i in range(2,9):
    indexes.append(i**2)

    aux = dfSolAlt[dfSolAlt['solveTime'] < 1800.0]
    times = aux.loc[aux['numVirtualPositions'] == i**2]['numUAVs'].array
    means_alt.append(np.mean(times))
    error_alt.append(np.std(times)/np.sqrt(len(times)))

    times = dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == i**2]['numUAVs'].array
    means_biobj.append(np.mean(times))
    error_biobj.append(np.std(times)/np.sqrt(len(times)))

    times = dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == i**2]['numUAVs'].array
    means_opt.append(np.mean(times))
    error_opt.append(np.std(times)/np.sqrt(len(times)))

fig = plt.figure(figsize=(7, 3))

color1 = '#6B2D97'
color2 = '#96753C'
color3 = '#1E9650'
alpha = 0.9

plt.errorbar(range(len(means_alt)), means_biobj, error_biobj, color=color2, marker='o', 
             label='Biobjective Alpha', capsize=6, lw=2, capthick=2)

plt.errorbar(range(len(means_alt)), means_alt, error_alt, color=color1, marker='o', 
             label='Biobjective Beta', capsize=6, lw=2, capthick=2)

# plt.errorbar(range(len(means_alt)), means_opt, error_opt, color=color3, marker='o', 
#              label='Minimize UAVs', capsize=6, lw=2, capthick=2)


plt.xticks(range(len(means_alt)), indexes)
plt.xlabel("Virtual Positions")
plt.ticklabel_format()
plt.ylabel("Mean Deployed UAVs")
plt.grid(True, 'major', 'y', linestyle='--')
plt.legend(loc='best')

# fig.suptitle('Solving Time by Number of Virtual Positions')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

means_biobj = []
error_biobj = []
indexes = []

pathCWD = os.getcwd() + "/data/"
pathFile = pathCWD + "model/output/beta_biobj_solutions.dat"
dataSolAlt = pd.read_csv(pathFile, sep=",")
dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_solutions.dat"
dataSolBiobj = pd.read_csv(pathFile, sep=",")
dfSolBiobj = pd.DataFrame(dataSolBiobj)

pathFile = pathCWD + "model/output/opt_solutions.dat"
dataSolOpt = pd.read_csv(pathFile, sep=",")
dfSolOpt = pd.DataFrame(dataSolOpt)

aux = dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == 25]
aux = aux[aux['solveTime'] < 1800.0]
for i in range(1,10):
    indexes.append(i*10)

    times = aux.loc[aux['numDevices'] == i*10]['solveTime'].array
    means_biobj.append(np.mean(times))
    error_biobj.append(np.std(times)/np.sqrt(len(times)))

fig, ax1 = plt.subplots(figsize=(7, 3))

color1 = '#6B2D97'
color2 = '#96753C'
color3 = '#1E9650'
color4 = "darkred"
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color1, marker='o', 
             label='Biobjective Alpha', capsize=6, lw=2, capthick=2)


ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of LoRa Devices")
# plt.ticklabel_format()
ax1.set_ylabel("Solve Time (s)")
ax1.legend(loc='best')

ax2 = ax1.twinx()

err = [0, 0, 0, 0, 0, 1, 9, 0, 10]
ax2.bar(range(len(means_biobj)), err, width=0.6, color='red', alpha=alpha, zorder=0)

ax2.set_ylabel('Number Unsolved Instances', color=color4)
ax2.tick_params(axis='y', which='major', colors=color4)
ax2.grid(True, 'major', 'y', linestyle='--', color=color4, alpha=0.4)

ax1.set_zorder(ax2.get_zorder()+1)
ax1.set_frame_on(False)

# fig.suptitle('Solving Time by Number of Virtual Positions')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

means_biobj = []
error_biobj = []
indexes = []

pathCWD = os.getcwd() + "/data/"

pathFile = pathCWD + "model/output/biobj_solutions.dat"
dataSolBiobj = pd.read_csv(pathFile, sep=",")
dfSolBiobj = pd.DataFrame(dataSolBiobj)

aux = dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == 25]
aux = aux[aux['solveTime'] < 1800.0]
for i in range(1,10):
    indexes.append(i*10)

    times = aux.loc[aux['numDevices'] == i*10]['numUAVs'].array
    means_biobj.append(np.mean(times))
    error_biobj.append(np.std(times)/np.sqrt(len(times)))

fig, ax1 = plt.subplots(figsize=(7, 3))

color1 = '#6B2D97'
color2 = '#96753C'
color3 = '#1E9650'
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color1, marker='o', 
             label='Biobjective Alpha', capsize=6, lw=2, capthick=2)


ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of LoRa Devices")
# plt.ticklabel_format()
ax1.set_yticks([0, 1, 2, 3, 4, 5])
ax1.set_ylabel("Mean Deployed UAVs")
ax1.grid(True, 'major', 'y', linestyle='--')
ax1.legend(loc='upper left')

ax2 = ax1.twinx()

err = [0, 0, 0, 0, 0, 1, 9, 0, 10]
ax2.bar(range(len(means_biobj)), err, width=0.6, color='red', alpha=alpha, zorder=0)

ax2.set_ylabel('Number Unsolved Instances', color=color4)
ax2.tick_params(axis='y', which='major', colors=color4)
# ax2.grid(True, 'major', 'y', linestyle='--', alpha=0.4)

ax1.set_zorder(ax2.get_zorder()+1)
ax1.set_frame_on(False)

# fig.suptitle('Solving Time by Number of Virtual Positions')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

means_alt = []
error_alt = []
means_biobj = []
error_biobj = []
indexes = []
solve_rate = {10: 0.0, 20: 0.0, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.0, 90: 0.0}
solved_seeds = {10: [], 20: [], 30: [], 40: [], 50: [], 60: [], 70: [], 80: [], 90: []}

pathCWD = os.getcwd() + "/data/"
# pathFile = pathCWD + "model/output/beta_biobj_solutions.dat"
# dataSolAlt = pd.read_csv(pathFile, sep=",")
# dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_solutions.dat"
dataSol = pd.read_csv(pathFile, sep=",")
dfSol = pd.DataFrame(dataSol)

dfSol = dfSol.loc[dfSol['numVirtualPositions'] == 25]

# for row in dfSolAlt.iterrows():
#     pos = row[1]['numVirtualPositions']
#     if row[1]['solveTime'] < 1800.0:
#         solve_rate[pos] += 10
#         solved_seeds[pos].append(row[1]['seed'])

for row in dfSol.iterrows():
    pos = row[1]['numDevices']
    if pos == 75:
        continue
    if row[1]['solveTime'] < 1800.0:
        solve_rate[pos] += 1
        solved_seeds[pos].append(row[1]['seed'])

for i in range(1,10):
    indexes.append(i*10)

    # ---- Biobjective Beta ----
    # pathFile = pathCWD + "results/beta_biobj_PacketDelivery_"+ str(i**2) +"x50.dat"
    # dataPkt = pd.read_csv(pathFile, sep=",")
    # dfPkt = pd.DataFrame(dataPkt)

    # delivery = []
    # for row in dfPkt.iterrows():
    #     if row[1]['seed'] not in solved_seeds[i**2]:
    #         continue
    #     delivery.append(row[1]['received'] / row[1]['sent'])
    
    # means_alt.append(np.mean(delivery) * 100)
    # error_alt.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

    # ---- Biobjective Alpha ----
    pathFile = pathCWD + "results/biobj_PacketDelivery_25x"+ str(i*10) +".dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        if row[1]['seed'] not in solved_seeds[i*10]:
            continue
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_biobj.append(np.mean(delivery) * 100)
    error_biobj.append(np.std(delivery) * 100/np.sqrt(len(delivery)))


fig, ax1 = plt.subplots(figsize=(7, 3))

color1 = '#6B2D97'
color2 = '#96753C'
color3 = '#1E9650'
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color1, marker='o', 
             label='Biobjective Alpha', capsize=6, lw=2, capthick=2, zorder=5)
# ax1.errorbar(range(len(means_alt)), means_alt, error_alt, color=color1, marker='o', 
#              label='Biobjective Beta', capsize=6, lw=2, capthick=2, zorder=5)

ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of LoRa Devices")
ax1.set_ylabel("Packet Delivery (%)")
ax1.grid(True, 'major', 'y', linestyle='--', color='darkgrey')
ax1.legend(loc='lower left')

ax2 = ax1.twinx()

ax2.bar(range(len(means_biobj)), [10 - i for i in solve_rate.values()], width=0.6, color='red', alpha=alpha, zorder=0)

ax2.set_ylabel('Unsolved Instances', color='darkred')
ax2.tick_params(axis='y', which='major', colors='darkred')

ax1.set_zorder(ax2.get_zorder()+1)
ax1.set_frame_on(False)
# fig.suptitle('Solving Time by Number of Virtual Positions')
plt.show()
# Out:
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

means_alt = []
error_alt = []
means_biobj = []
error_biobj = []
means_biobj_dr = []
error_biobj_dr = []
indexes = []
solve_rate = {10: 0.0, 20: 0.0, 30: 0.0, 40: 0.0, 50: 0.0, 60: 0.0, 70: 0.0, 80: 0.0, 90: 0.0}
solved_seeds = {10: [], 20: [], 30: [], 40: [], 50: [], 60: [], 70: [], 80: [], 90: []}

pathCWD = os.getcwd() + "/data/"
# pathFile = pathCWD + "model/output/beta_biobj_solutions.dat"
# dataSolAlt = pd.read_csv(pathFile, sep=",")
# dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_solutions.dat"
dataSol = pd.read_csv(pathFile, sep=",")
dfSol = pd.DataFrame(dataSol)

dfSol = dfSol.loc[dfSol['numVirtualPositions'] == 25]

# for row in dfSolAlt.iterrows():
#     pos = row[1]['numVirtualPositions']
#     if row[1]['solveTime'] < 1800.0:
#         solve_rate[pos] += 10
#         solved_seeds[pos].append(row[1]['seed'])

for row in dfSol.iterrows():
    pos = row[1]['numDevices']
    if pos == 75:
        continue
    if row[1]['solveTime'] < 1800.0:
        solve_rate[pos] += 1
        solved_seeds[pos].append(row[1]['seed'])

for i in range(1,10):
    indexes.append(i*10)

    # ---- Biobjective Beta ----
    # pathFile = pathCWD + "results/beta_biobj_PacketDelivery_"+ str(i**2) +"x50.dat"
    # dataPkt = pd.read_csv(pathFile, sep=",")
    # dfPkt = pd.DataFrame(dataPkt)

    # delivery = []
    # for row in dfPkt.iterrows():
    #     if row[1]['seed'] not in solved_seeds[i**2]:
    #         continue
    #     delivery.append(row[1]['received'] / row[1]['sent'])
    
    # means_alt.append(np.mean(delivery) * 100)
    # error_alt.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

    # ---- Biobjective Alpha ----
    delivery = []
    datarate = []

    for s in range(1,11):
        if s not in solved_seeds[i*10]:
            continue

        pathFile = pathCWD + "results/biobj_transmissionPackets_"+ str(s) +"_25x"+ str(i*10) +".dat"
        dataPkt = pd.read_csv(pathFile, sep=",")
        dfPkt = pd.DataFrame(dataPkt)

        delivery += [x for x in dfPkt['throughput'].array]

        pathFile = pathCWD + "results/biobj_EDParameters_"+ str(s) +"_25x"+ str(i*10) +".dat"
        dataPkt = pd.read_csv(pathFile, sep=",")
        dfPkt = pd.DataFrame(dataPkt)

        datarate += [x for x in dfPkt['datarate'].array]
    
    means_biobj.append(np.mean(delivery))
    error_biobj.append(np.std(delivery)/np.sqrt(len(delivery)))

    means_biobj_dr.append(np.mean(datarate))
    error_biobj_dr.append(np.std(datarate)/np.sqrt(len(datarate)))


fig, ax1 = plt.subplots(figsize=(7, 3))

color1 = '#6B2D97'
color2 = '#96753C'
color3 = '#1E9650'
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color1, marker='o', 
             label='Simulation Throughput', capsize=6, lw=2, capthick=2, zorder=5)
ax1.errorbar(range(len(means_biobj)), means_biobj_dr, error_biobj_dr, color=color3, marker='o', 
             label='Solution Datarate', capsize=6, lw=2, capthick=2, zorder=5)
# ax1.errorbar(range(len(means_alt)), means_alt, error_alt, color=color1, marker='o', 
#              label='Biobjective Beta', capsize=6, lw=2, capthick=2, zorder=5)

ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of LoRa Devices")
ax1.set_ylabel("Datarate (bits/s)")
ax1.grid(True, 'major', 'y', linestyle='--', color='darkgrey')
ax1.legend(loc='lower left')

ax2 = ax1.twinx()

ax2.bar(range(len(means_biobj)), [10 - i for i in solve_rate.values()], width=0.6, color='red', alpha=alpha, zorder=0)

ax2.set_ylabel('Unsolved Instances', color='darkred')
ax2.tick_params(axis='y', which='major', colors='darkred')

ax1.set_zorder(ax2.get_zorder()+1)
ax1.set_frame_on(False)
# fig.suptitle('Solving Time by Number of Virtual Positions')
plt.show()
# Out:
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/sdran/miniconda3/lib/python3.11/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
import numpy as np
from matplotlib import rcParams
import matplotlib.pyplot as plt
import pandas as pd
import os

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

means_beta = []
error_beta = []
means_beta_gap = []
error_beta_gap = []
means_biobj = []
error_biobj = []
means_biobj_gap = []
error_biobj_gap = []
means_opt = []
error_opt = []
indexes = []

pathCWD = os.getcwd() + "/data/"
pathFile = pathCWD + "model/output/beta_biobj_gap_solutions.dat"
dataSolAlt = pd.read_csv(pathFile, sep=",")
dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_gap_solutions.dat"
dataSol = pd.read_csv(pathFile, sep=",")
dfSol = pd.DataFrame(dataSol)

dfSol = dfSol.loc[dfSol['numVirtualPositions'] == 25]
dfSolAlt = dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == 25]

for i in range(1,10):
    indexes.append(i*10)

    # ---- Biobjective Alpha ----
    pathFile = pathCWD + "results/biobj_gap_PacketDelivery_25x"+ str(i*10) +".dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_biobj.append(np.mean(delivery) * 100)
    error_biobj.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

    gaps = dfSol.loc[dfSol['numDevices'] == i*10]['gap'].array
    means_biobj_gap.append(np.mean(gaps))
    error_biobj_gap.append(np.std(gaps) / np.sqrt(len(gaps)))

    # ---- Biobjective Beta ----
    pathFile = pathCWD + "results/beta_biobj_gap_PacketDelivery_25x"+ str(i*10) +".dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_beta.append(np.mean(delivery) * 100)
    error_beta.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

    gaps = dfSolAlt.loc[dfSolAlt['numDevices'] == i*10]['gap'].array
    means_beta_gap.append(np.mean(gaps))
    error_beta_gap.append(np.std(gaps) / np.sqrt(len(gaps)))

    # ---- Mono-objective ----
    pathFile = pathCWD + "results/opt_gap_PacketDelivery_25x"+ str(i*10) +".dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_opt.append(np.mean(delivery) * 100)
    error_opt.append(np.std(delivery) * 100/np.sqrt(len(delivery)))


fig, ax1 = plt.subplots(figsize=(7, 4))

color1 = '#643299'
color2 = '#994032'
color3 = '#993280'
color4 = '#993242'
color5 = '#853299'
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color1, mfc='white', marker='o', markersize=10,
             linestyle='', label='BMinUAV', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_beta)), means_beta, error_beta, color=color3, mec='white', marker='X', markersize=10,
             linestyle='', label='BMinSF', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_opt)), means_opt, error_opt, color=color2, mec='white', marker='D', markersize=7,
             linestyle='', label='MMinUAV', capsize=8, lw=2, capthick=2, zorder=6)


ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of LoRa Devices")
ax1.set_ylabel("Packet Delivery (%)")
ax1.tick_params(axis='y', which='major')
ax1.set_ylim(60)
ax1.grid(True, 'major', 'y', linestyle='--', color='darkgrey', zorder=0)

# ax2 = ax1.twinx()

# ax2.errorbar(range(len(means_biobj_gap)), means_biobj_gap, error_biobj_gap, color=color2, markersize=6, 
#              mfc='white', marker='o', label='BMinUAV Gap', capsize=4, lw=2, capthick=2, zorder=5)
# ax2.errorbar(range(len(means_beta_gap)), means_beta_gap, error_beta_gap, color=color2, markersize=10, 
#              linestyle='--', mec='white', marker='X', label='BMinSF Gap', capsize=4, lw=2, capthick=2, zorder=5)

# ax2.set_ylabel('MIP Gap (%)', color=color2)
# ax2.tick_params(axis='y', which='major', colors=color2)
# ax2.set_ylim(top=4.0)

ax1.set_zorder(ax2.get_zorder()+1)
# ax1.set_frame_on(False)

bars, labels = ax1.get_legend_handles_labels()
# bars2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(bars+bars2, labels+labels2, loc='best')
# fig.suptitle('Solving Time by Number of Virtual Positions')
# plt.show()
plt.savefig('fig/packet_delivery_per_device_density.pdf', format='pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
from matplotlib import rcParams
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

means_alt = []
error_alt = []
means_biobj = []
error_biobj = []
means_biobj_dr = []
error_biobj_dr = []
means_biobj_gap = []
error_biobj_gap = []
indexes = []

pathCWD = os.getcwd() + "/data/"
# pathFile = pathCWD + "model/output/beta_biobj_solutions.dat"
# dataSolAlt = pd.read_csv(pathFile, sep=",")
# dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_gap_solutions.dat"
dataSol = pd.read_csv(pathFile, sep=",")
dfSol = pd.DataFrame(dataSol)

dfSol = dfSol.loc[dfSol['numVirtualPositions'] == 25]


for i in range(1,10):
    indexes.append(i*10)

    # ---- Biobjective Beta ----
    # pathFile = pathCWD + "results/beta_biobj_PacketDelivery_"+ str(i**2) +"x50.dat"
    # dataPkt = pd.read_csv(pathFile, sep=",")
    # dfPkt = pd.DataFrame(dataPkt)

    # delivery = []
    # for row in dfPkt.iterrows():
    #     if row[1]['seed'] not in solved_seeds[i**2]:
    #         continue
    #     delivery.append(row[1]['received'] / row[1]['sent'])
    
    # means_alt.append(np.mean(delivery) * 100)
    # error_alt.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

    # ---- Biobjective Alpha ----
    delivery = []
    datarate = []

    for s in range(1,11):
        pathFile = pathCWD + "results/biobj_gap_transmissionPackets_"+ str(s) +"_25x"+ str(i*10) +".dat"
        dataPkt = pd.read_csv(pathFile, sep=",")
        dfPkt = pd.DataFrame(dataPkt)

        delivery += [x for x in dfPkt['throughput'].array]

        pathFile = pathCWD + "results/biobj_gap_EDParameters_"+ str(s) +"_25x"+ str(i*10) +".dat"
        dataPkt = pd.read_csv(pathFile, sep=",")
        dfPkt = pd.DataFrame(dataPkt)

        datarate += [x for x in dfPkt['datarate'].array]
    
    means_biobj.append(np.mean(delivery))
    error_biobj.append(np.std(delivery)/np.sqrt(len(delivery)))

    means_biobj_dr.append(np.mean(datarate))
    error_biobj_dr.append(np.std(datarate)/np.sqrt(len(datarate)))

    gaps = dfSol.loc[dfSol['numDevices'] == i*10]['gap'].array
    means_biobj_gap.append(np.mean(gaps))
    error_biobj_gap.append(np.std(gaps) / np.sqrt(len(gaps)))


fig, ax1 = plt.subplots(figsize=(7, 4))

color1 = '#643299'
color2 = '#994032'
color3 = '#993280'
color4 = '#996F32'
color5 = '#297C43'
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj_dr, error_biobj_dr, color=color1, marker='X', markersize=10,
             linestyle='', mec='white', label='Theoretical', capsize=8, lw=2, capthick=2, zorder=5)
ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color4, marker='s', markersize=8, 
             linestyle='', mec='white', label='Simulated', capsize=8, lw=2, capthick=3, zorder=5)

ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of LoRa Devices")
ax1.set_ylabel("Data Rate / Throughput (bits/s)")
ax1.grid(True, 'major', 'y', linestyle='--', color='darkgrey')
ax1.set_ylim(0, 3000)

# ax2 = ax1.twinx()

# ax2.errorbar(range(len(means_biobj_gap)), means_biobj_gap, error_biobj_gap, color=color2, markersize=6, 
#              mfc='white', marker='o', linestyle='--', label='MIP Gap', capsize=4, lw=2, capthick=2, zorder=5)

# ax2.set_ylabel('MIP Gap (%)', color=color2)
# ax2.tick_params(axis='y', which='major', colors=color2)
# ax2.set_ylim(top=10)

bars, labels = ax1.get_legend_handles_labels()
# bars2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(bars+bars2, labels+labels2, loc='best')

ax1.set_zorder(ax2.get_zorder()+1)
# ax1.set_frame_on(False)
# fig.suptitle('Solving Time by Number of Virtual Positions')
# plt.show()
plt.savefig('fig/datarate_per_device_density.pdf', format='pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
from matplotlib import rcParams
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

means_alt = []
error_alt = []
means_biobj = []
error_biobj = []
means_biobj_dr = []
error_biobj_dr = []
means_biobj_gap = []
error_biobj_gap = []
indexes = []

pathCWD = os.getcwd() + "/data/"
# pathFile = pathCWD + "model/output/beta_biobj_solutions.dat"
# dataSolAlt = pd.read_csv(pathFile, sep=",")
# dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_gap_solutions.dat"
dataSol = pd.read_csv(pathFile, sep=",")
dfSol = pd.DataFrame(dataSol)

dfSol = dfSol.loc[dfSol['numVirtualPositions'] == 25]

PACKET_SIZE = 400 - 13*8
MIN_RKC = 183.11
MAX_DELAY = PACKET_SIZE / MIN_RKC


for i in range(1,10):
    indexes.append(i*10)

    # ---- Biobjective Beta ----
    # pathFile = pathCWD + "results/beta_biobj_PacketDelivery_"+ str(i**2) +"x50.dat"
    # dataPkt = pd.read_csv(pathFile, sep=",")
    # dfPkt = pd.DataFrame(dataPkt)

    # delivery = []
    # for row in dfPkt.iterrows():
    #     if row[1]['seed'] not in solved_seeds[i**2]:
    #         continue
    #     delivery.append(row[1]['received'] / row[1]['sent'])
    
    # means_alt.append(np.mean(delivery) * 100)
    # error_alt.append(np.std(delivery) * 100/np.sqrt(len(delivery)))

    # ---- Biobjective Alpha ----
    delivery = []
    datarate = []

    for s in range(1,11):
        pathFile = pathCWD + "results/biobj_gap_transmissionPackets_"+ str(s) +"_25x"+ str(i*10) +".dat"
        dataPkt = pd.read_csv(pathFile, sep=",")
        dfPkt = pd.DataFrame(dataPkt)

        delivery += [x for x in dfPkt['delay'].array if x >= 0.0]

        pathFile = pathCWD + "model/output/biobj_gap_QoSResults_"+ str(s) +"s_25x1Gv_"+ str(i*10) +"D.dat"
        dataPkt = pd.read_csv(pathFile, sep=",")
        dfPkt = pd.DataFrame(dataPkt)

        datarate += [(1 - x) * MAX_DELAY for x in dfPkt['delay'].array]
    
    means_biobj.append(np.mean(delivery))
    error_biobj.append(np.std(delivery)/np.sqrt(len(delivery)))

    means_biobj_dr.append(np.mean(datarate))
    error_biobj_dr.append(np.std(datarate)/np.sqrt(len(datarate)))

    gaps = dfSol.loc[dfSol['numDevices'] == i*10]['gap'].array
    means_biobj_gap.append(np.mean(gaps))
    error_biobj_gap.append(np.std(gaps) / np.sqrt(len(gaps)))


fig, ax1 = plt.subplots(figsize=(7, 4))

color1 = '#643299'
color2 = '#994032'
color3 = '#993280'
color4 = '#996F32'
color5 = '#297C43'
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color4, mec='white', marker='s', markersize=8,
             linestyle='', label='Simulated', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_biobj_dr)), means_biobj_dr, error_biobj_dr, color=color1, marker='X', markersize=10,
             linestyle='', mec='white', label='Theoretical', capsize=8, lw=2, capthick=2, zorder=5)


ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of LoRa Devices")
ax1.set_ylabel("Transmission Delay (s)")
ax1.grid(True, 'major', 'y', linestyle='--', color='darkgrey')
ax1.set_ylim(0, 0.6)

# ax2 = ax1.twinx()

# ax2.errorbar(range(len(means_biobj_gap)), means_biobj_gap, error_biobj_gap, color=color2, markersize=6, 
#              mfc='white', marker='o', linestyle='--', label='MIP Gap', capsize=4, lw=2, capthick=2, zorder=5)

# ax2.set_ylabel('MIP Gap (%)', color=color2)
# ax2.tick_params(axis='y', which='major', colors=color2)
# ax2.set_ylim(top=10.0)

bars, labels = ax1.get_legend_handles_labels()
# bars2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(bars+bars2, labels+labels2, loc='upper left')

ax1.set_zorder(ax2.get_zorder()+1)
# ax1.set_frame_on(False)
# fig.suptitle('Solving Time by Number of Virtual Positions')
# plt.show()
plt.savefig('fig/delay_per_device_density.pdf', format='pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
from matplotlib import rcParams
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

means_biobj = []
error_biobj = []
means_biobj_gap = []
error_biobj_gap = []
means_beta = []
error_beta = []
means_beta_gap = []
error_beta_gap = []
means_opt = []
error_opt = []
indexes = []

pathCWD = os.getcwd() + "/data/"

pathFile = pathCWD + "model/output/biobj_gap_solutions.dat"
dataSolBiobj = pd.read_csv(pathFile, sep=",")
dfSolBiobj = pd.DataFrame(dataSolBiobj)

pathFile = pathCWD + "model/output/beta_biobj_gap_solutions.dat"
dataSolBeta = pd.read_csv(pathFile, sep=",")
dfSolBeta = pd.DataFrame(dataSolBeta)

pathFile = pathCWD + "model/output/opt_gap_solutions.dat"
dataSolOpt = pd.read_csv(pathFile, sep=",")
dfSolOpt = pd.DataFrame(dataSolOpt)

dfSolBiobj = dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == 25]
dfSolBeta = dfSolBeta.loc[dfSolBeta['numVirtualPositions'] == 25]
dfSolOpt = dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == 25]
for i in range(1,10):
    indexes.append(i*10)

    # ------ Biobjective Alpha ------
    times = dfSolBiobj.loc[dfSolBiobj['numDevices'] == i*10]['numUAVs'].array
    means_biobj.append(np.mean(times))
    error_biobj.append(np.std(times)/np.sqrt(len(times)))

    gaps = dfSolBiobj.loc[dfSolBiobj['numDevices'] == i*10]['gap'].array
    means_biobj_gap.append(np.mean(gaps))
    error_biobj_gap.append(np.std(gaps) / np.sqrt(len(gaps)))

    # ------ Biobjective Beta ------
    times = dfSolBeta.loc[dfSolBeta['numDevices'] == i*10]['numUAVs'].array
    means_beta.append(np.mean(times))
    error_beta.append(np.std(times)/np.sqrt(len(times)))

    gaps = dfSolBeta.loc[dfSolBeta['numDevices'] == i*10]['gap'].array
    means_beta_gap.append(np.mean(gaps))
    error_beta_gap.append(np.std(gaps) / np.sqrt(len(gaps)))

    # ------ Mono-Objective ------
    times = dfSolOpt.loc[dfSolOpt['numDevices'] == i*10]['numUAVs'].array
    means_opt.append(np.mean(times))
    error_opt.append(np.std(times)/np.sqrt(len(times)))


fig, ax1 = plt.subplots(figsize=(7, 4))

color1 = '#643299'
color2 = '#994032'
color3 = '#993280'
color4 = '#996F32'
color5 = '#297C43'
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color1, mfc='white', marker='o', markersize=10,
             linestyle='', label='BMinUAV', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_beta)), means_beta, error_beta, color=color3, mec='white', marker='X', markersize=10,
             linestyle='', label='BMinSF', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_opt)), means_opt, error_opt, color=color2, mec='white', marker='D', markersize=7,
             linestyle='', label='MMinUAV', capsize=8, lw=2, capthick=2, zorder=6)


ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of LoRa Devices")
# plt.ticklabel_format()
ax1.set_ylim(0, 10)
ax1.set_ylabel("Mean Deployed UAVs")
ax1.tick_params(axis='y', which='major')
ax1.grid(True, 'major', 'y', linestyle='--')

# ax2 = ax1.twinx()

# ax2.errorbar(range(len(means_biobj_gap)), means_biobj_gap, error_biobj_gap, color=color2, markersize=8, 
#              linestyle='', mfc='white', marker='o', label='BMinUAV Gap', capsize=6, lw=2, capthick=2, zorder=5)
# ax2.errorbar(range(len(means_beta_gap)), means_beta_gap, error_beta_gap, color=color2, markersize=10, 
#              linestyle='', mec='white', marker='X', label='BMinSF Gap', capsize=4, lw=2, capthick=2, zorder=5)

# ax2.set_ylabel('MIP Gap (%)', color=color2)
# ax2.tick_params(axis='y', which='major', colors=color2)
# ax2.grid(True, 'major', 'y', linestyle='--', alpha=0.4)
# ax2.set_ylim(top=10.0)

bars, labels = ax1.get_legend_handles_labels()
# bars2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(bars+bars2, labels+labels2, loc='upper left')

ax1.set_zorder(ax2.get_zorder()+1)
# ax1.set_frame_on(False)

# fig.suptitle('Solving Time by Number of Virtual Positions')
# plt.show()
plt.savefig('fig/mean_uavs_per_device_density.pdf', format='pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
from matplotlib import rcParams
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

means_beta = []
error_beta = []
means_beta_gap = []
error_beta_gap = []
means_biobj = []
error_biobj = []
means_biobj_gap = []
error_biobj_gap = []
means_opt = []
error_opt = []
indexes = []

pathCWD = os.getcwd() + "/data/"
pathFile = pathCWD + "model/output/beta_biobj_gap_solutions.dat"
dataSolAlt = pd.read_csv(pathFile, sep=",")
dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_gap_solutions.dat"
dataSolBiobj = pd.read_csv(pathFile, sep=",")
dfSolBiobj = pd.DataFrame(dataSolBiobj)

pathFile = pathCWD + "model/output/opt_gap_solutions.dat"
dataSolOpt = pd.read_csv(pathFile, sep=",")
dfSolOpt = pd.DataFrame(dataSolOpt)

for i in range(1,10):
    indexes.append(i*10)

    # ----- Beta Biobjective -----
    times = dfSolAlt.loc[dfSolAlt['numDevices'] == i*10]['solveTime'].array
    means_beta.append(np.mean(times))
    error_beta.append(np.std(times)/np.sqrt(len(times)))

    gaps = dfSolAlt.loc[dfSolAlt['numDevices'] == i*10]['gap'].array
    means_beta_gap.append(np.mean(gaps))
    error_beta_gap.append(np.std(gaps) / np.sqrt(len(gaps)))

    # ----- Alpha Biobjective -----
    times = dfSolBiobj.loc[dfSolBiobj['numDevices'] == i*10]['solveTime'].array
    means_biobj.append(np.mean(times))
    error_biobj.append(np.std(times)/np.sqrt(len(times)))

    gaps = dfSolBiobj.loc[dfSolBiobj['numDevices'] == i*10]['gap'].array
    means_biobj_gap.append(np.mean(gaps))
    error_biobj_gap.append(np.std(gaps) / np.sqrt(len(gaps)))

    # ----- Mono-objective -----
    times = dfSolOpt.loc[dfSolOpt['numDevices'] == i*10]['solveTime'].array
    means_opt.append(np.mean(times))
    error_opt.append(np.std(times)/np.sqrt(len(times)))

fig, ax1 = plt.subplots(figsize=(7, 4))

color1 = '#643299'
color2 = '#994032'
color3 = '#993280'
color4 = '#996F32'
color5 = '#297C43'
alpha = 0.9

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color1, mfc='white', marker='o', markersize=10,
             linestyle='', label='BMinUAV', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_beta)), means_beta, error_beta, color=color1, mec='white', marker='X', markersize=10,
             linestyle='', label='BMinSF', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_opt)), means_opt, error_opt, color=color1, mec='white', marker='D', markersize=8,
             linestyle='', label='MMinUAV', capsize=8, lw=2, capthick=2, zorder=6)


ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of LoRa Devices")
ax1.set_ylabel("Solve Time (s)", color=color1)
ax1.tick_params(axis='y', which='major', colors=color1)
ax1.set_ylim(0, 2500.0)
ax1.set_yscale('symlog')
ax1.grid(True, 'major', 'y', linestyle='--')

ax2 = ax1.twinx()

ax2.errorbar(range(len(means_biobj_gap)), means_biobj_gap, error_biobj_gap, color=color4, markersize=10, 
             linestyle='', mfc='white', marker='o', label='BMinUAV Gap', capsize=8, lw=2, capthick=2, zorder=5)
ax2.errorbar(range(len(means_beta_gap)), means_beta_gap, error_beta_gap, color=color4, markersize=10, 
             linestyle='', mec='white', marker='X', label='BMinSF Gap', capsize=8, lw=2, capthick=2, zorder=5)

ax2.set_ylabel('MIP Gap (%)', color=color4)
ax2.tick_params(axis='y', which='major', colors=color4)
ax2.set_ylim(top=10.0)

bars, labels = ax1.get_legend_handles_labels()
bars2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(bars+bars2, labels+labels2, loc='best')

ax1.set_zorder(ax2.get_zorder()+1)
ax1.set_frame_on(False)

# fig.suptitle('Solving Time by Number of Virtual Positions')
# plt.show()
plt.savefig('fig/time_per_device_density.pdf', format='pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
from matplotlib import rcParams
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

means_beta = []
error_beta = []
means_beta_gap = []
error_beta_gap = []
means_biobj = []
error_biobj = []
means_biobj_gap = []
error_biobj_gap = []
means_opt = []
error_opt = []
indexes = []

pathCWD = os.getcwd() + "/data/"
pathFile = pathCWD + "model/output/beta_biobj_gap_solutions.dat"
dataSolAlt = pd.read_csv(pathFile, sep=",")
dfSolAlt = pd.DataFrame(dataSolAlt)

pathFile = pathCWD + "model/output/biobj_solutions.dat"
dataSolBiobj = pd.read_csv(pathFile, sep=",")
dfSolBiobj = pd.DataFrame(dataSolBiobj)

pathFile = pathCWD + "model/output/opt_solutions.dat"
dataSolOpt = pd.read_csv(pathFile, sep=",")
dfSolOpt = pd.DataFrame(dataSolOpt)

dfSolAlt = dfSolAlt.loc[dfSolAlt['numDevices'] == 50]
dfSolBiobj = dfSolBiobj.loc[dfSolBiobj['numDevices'] == 50]
dfSolOpt = dfSolOpt.loc[dfSolOpt['numDevices'] == 50]

for i in range(2,9):
    indexes.append(i**2)

    # ----- Beta Biobjective -----
    times = dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == i**2]['solveTime'].array
    means_beta.append(np.mean(times))
    error_beta.append(np.std(times))

    gaps = dfSolAlt.loc[dfSolAlt['numVirtualPositions'] == i**2]['gap'].array
    means_beta_gap.append(np.mean(gaps))
    error_beta_gap.append(np.std(gaps)/ np.sqrt(len(gaps)))

    # ----- Alpha Biobjective -----
    times = dfSolBiobj.loc[dfSolBiobj['numVirtualPositions'] == i**2]['solveTime'].array
    means_biobj.append(np.mean(times))
    error_biobj.append(np.std(times))

    # ----- Mono-objective -----
    times = dfSolOpt.loc[dfSolOpt['numVirtualPositions'] == i**2]['solveTime'].array
    means_opt.append(np.mean(times))
    error_opt.append(np.std(times))

fig, ax1 = plt.subplots(figsize=(7, 4))

color1 = '#643299'
color2 = '#994032'
color3 = '#993280'
color4 = '#996F32'
color5 = '#297C43'
alpha = 0.9

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color1, mfc='white', marker='o', markersize=10,
             linestyle='', label='BMinUAV', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_beta)), means_beta, error_beta, color=color1, mec='white', marker='X', markersize=10,
             linestyle='', label='BMinSF', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_opt)), means_opt, error_opt, color=color1, mec='white', marker='D', markersize=8,
             linestyle='', label='MMinUAV', capsize=8, lw=2, capthick=2, zorder=6)


ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of Candidate Positions")
ax1.set_ylabel("Solve Time (s)", color=color1)
ax1.tick_params(axis='y', which='major', colors=color1)
ax1.set_ylim(0, 2500.0)
ax1.set_yscale('symlog')
ax1.grid(True, 'major', 'y', linestyle='--')

ax2 = ax1.twinx()

# ax2.errorbar(range(len(means_biobj_gap)), means_biobj_gap, error_biobj_gap, color=color4, markersize=10, 
#              linestyle='', mfc='white', marker='o', label='BMinUAV Gap', capsize=8, lw=2, capthick=2, zorder=5)
ax2.errorbar(range(len(means_beta_gap)), means_beta_gap, error_beta_gap, color=color4, markersize=10, 
             linestyle='', mec='white', marker='X', label='BMinSF Gap', capsize=8, lw=2, capthick=2, zorder=5)

ax2.set_ylabel('MIP Gap (%)', color=color4)
ax2.tick_params(axis='y', which='major', colors=color4)
ax2.set_ylim(top=1.0)

bars, labels = ax1.get_legend_handles_labels()
bars2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(bars+bars2, labels+labels2, loc='best')

ax1.set_zorder(ax2.get_zorder()+1)
ax1.set_frame_on(False)

# fig.suptitle('Solving Time by Number of Virtual Positions')
# plt.show()
plt.savefig('fig/time_per_candidate_position.pdf', format='pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
import numpy as np
from matplotlib import rcParams
import matplotlib.pyplot as plt
import pandas as pd
import os

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

means_beta = []
error_beta = []
means_biobj = []
error_biobj = []
means_opt = []
error_opt = []
indexes = []

pathCWD = os.getcwd() + "/data/"

for i in range(2,9):
    indexes.append(i**2)

    # ---- Biobjective Alpha ----
    pathFile = pathCWD + "results/biobj_PacketDelivery_" + str(i**2) + "x50.dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_biobj.append(np.mean(delivery) * 100)
    error_biobj.append(np.std(delivery) * 100)

    # ---- Biobjective Beta ----
    pathFile = pathCWD + "results/beta_biobj_gap_PacketDelivery_" + str(i**2) + "x50.dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_beta.append(np.mean(delivery) * 100)
    error_beta.append(np.std(delivery) * 100)

    # ---- Mono-objective ----
    pathFile = pathCWD + "results/opt_PacketDelivery_" + str(i**2) + "x50.dat"
    dataPkt = pd.read_csv(pathFile, sep=",")
    dfPkt = pd.DataFrame(dataPkt)

    delivery = []
    for row in dfPkt.iterrows():
        delivery.append(row[1]['received'] / row[1]['sent'])
    
    means_opt.append(np.mean(delivery) * 100)
    error_opt.append(np.std(delivery) * 100)


fig, ax1 = plt.subplots(figsize=(7, 4))

color1 = '#643299'
color2 = '#994032'
color3 = '#993280'
color4 = '#993242'
color5 = '#853299'
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color1, mfc='white', marker='o', markersize=10,
             linestyle='', label='BMinUAV', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_beta)), means_beta, error_beta, color=color3, mec='white', marker='X', markersize=10,
             linestyle='', label='BMinSF', capsize=8, lw=2, capthick=2, zorder=6)
ax1.errorbar(range(len(means_opt)), means_opt, error_opt, color=color2, mec='white', marker='D', markersize=7,
             linestyle='', label='MMinUAV', capsize=8, lw=2, capthick=2, zorder=6)

ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of Candidate Positions")
ax1.set_ylabel("Packet Delivery (%)")
ax1.tick_params(axis='y', which='major')
ax1.set_ylim(60)
ax1.grid(True, 'major', 'y', linestyle='--', color='darkgrey', zorder=0)

bars, labels = ax1.get_legend_handles_labels()
ax1.legend(bars, labels, loc='best')
# fig.suptitle('Solving Time by Number of Virtual Positions')
# plt.show()
plt.savefig('fig/packet_delivery_per_candidate_position.pdf', format='pdf', bbox_inches = 'tight', pad_inches = 0)

# %%
from matplotlib import rcParams
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

rcParams['font.family'] = 'serif'
rcParams['font.size'] = 12

means_alt = []
error_alt = []
means_biobj = []
error_biobj = []
means_biobj_dr = []
error_biobj_dr = []
indexes = []

pathCWD = os.getcwd() + "/data/"


for i in range(2,9):
    indexes.append(i**2)

    # ---- Biobjective Alpha ----
    throughput = []
    datarate = []

    for s in range(1,11):
        pathFile = pathCWD + "results/beta_biobj_gap_transmissionPackets_"+ str(s) +"_"+ str(i**2) +"x50.dat"
        dataPkt = pd.read_csv(pathFile, sep=",")
        dfPkt = pd.DataFrame(dataPkt)

        throughput += [x for x in dfPkt['throughput'].array]

        pathFile = pathCWD + "results/beta_biobj_gap_EDParameters_"+ str(s) +"_"+ str(i**2) +"x50.dat"
        dataPkt = pd.read_csv(pathFile, sep=",")
        dfPkt = pd.DataFrame(dataPkt)

        datarate += [x for x in dfPkt['datarate'].array]
    
    means_biobj.append(np.mean(throughput))
    error_biobj.append(np.std(throughput)/np.sqrt(len(throughput)))

    print(len(throughput))
    print(throughput)
    print('-------------')

    means_biobj_dr.append(np.mean(datarate))
    error_biobj_dr.append(np.std(datarate)/np.sqrt(len(datarate)))


fig, ax1 = plt.subplots(figsize=(7, 4))

color1 = '#643299'
color2 = '#994032'
color3 = '#993280'
color4 = '#996F32'
color5 = '#297C43'
alpha = 0.6

ax1.errorbar(range(len(means_biobj)), means_biobj_dr, error_biobj_dr, color=color1, marker='X', markersize=10,
             linestyle='', mec='white', label='Theoretical', capsize=8, lw=2, capthick=2, zorder=5)
ax1.errorbar(range(len(means_biobj)), means_biobj, error_biobj, color=color4, marker='s', markersize=8, 
             linestyle='', mec='white', label='Simulated', capsize=8, lw=2, capthick=3, zorder=5)

ax1.set_xticks(range(len(means_biobj)), indexes)
ax1.set_xlabel("Number of Candidate Locations")
ax1.set_ylabel("Data Rate / Throughput (bits/s)")
ax1.grid(True, 'major', 'y', linestyle='--', color='darkgrey')
ax1.set_ylim(0, 3000)

ax1.legend(loc='best')

# fig.suptitle('Solving Time by Number of Virtual Positions')
# plt.show()
plt.savefig('fig/datarate_per_candidate_position.pdf', format='pdf', bbox_inches = 'tight', pad_inches = 0)
# Out:
# 17138
# ...
